# %% [markdown]
# # 블린
#
# - 참(1), 거짓(0)을 가진다
# - True, False
# - 사용처
#   - 조건식의 결과물
#   - 이진 데이터를 표현할 때 사용
#   - 조건식에서 사용 시 False 상황을 기억한다
#     - False: 0, 0.0, '', [], {}, (,), None, NaN, 기타 조건의 결과
#     - 이것을 활용하면 조건식이 간결해진다
#     - False를 조건식에서 잡는 방법
#       - not 조건식
#       - if문에서 확인
