# %% [markdown]
# # 모듈 불러오기

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline\

# 한글 처리 (구글링)
# %config InlineBackend.figure_format = 'retina'
 
# !apt -qq -y install fonts-nanum
 
import matplotlib.font_manager as fm
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumBarunGothic') 
mpl.font_manager._rebuild()
# Out:
# fonts-nanum is already the newest version (20170925-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.

# %%
import numpy as np
import pandas as pd

# %%
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # 데이터 불러오기

# %%
td = pd.read_csv( '/content/drive/My Drive/Colab Notebooks/data_project/team_defense.csv', sep=',', encoding='cp949' )
tm_def = td.drop('Unnamed: 0', axis = 1)
tm_def
# Out:
#        연도   팀명    경기    실책  견제사      자살  ...    병살    수비율   포일  도루허용  도루실패  도루저지율
# 0    2001   키움  63.0  46.0  9.0  1670.0  ...  70.0  0.981  4.0  40.0  14.0   25.9
# 1    2001   LG  61.0  36.0  4.0  1645.0  ...  61.0  0.984  5.0  35.0  18.0   34.0
# 2    2001   삼성  62.0  41.0  4.0  1635.0  ...  61.0  0.982  1.0  27.0  15.0   35.7
# 3    2001   두산  61.0  39.0  4.0  1634.0  ...  55.0  0.982  2.0  30.0   9.0   23.1
# 4    2001   SK  62.0  46.0  2.0  1630.0  ...  59.0  0.980  1.0  66.0  22.0   25.0
# ..    ...  ...   ...   ...  ...     ...  ...   ...    ...  ...   ...   ...    ...
# 195  2020   NC  60.0  28.0  5.0  1626.0  ...  55.0  0.987  1.0  15.0  17.0   53.1
# 196  2020   KT  61.0  42.0  4.0  1624.0  ...  61.0  0.982  8.0  24.0   9.0   27.3
# 197  2020   한화  62.0  53.0  2.0  1621.0  ...  55.0  0.976  5.0  54.0  22.0   28.9
# 198  2020   롯데  59.0  31.0  0.0  1594.0  ...  58.0  0.986  4.0  39.0  13.0   25.0
# ...

# %%
th = pd.read_csv( '/content/drive/My Drive/Colab Notebooks/data_project/team_hitter.csv', sep=',', encoding='cp949' )
tm_hit = th.drop('Unnamed: 0', axis = 1)
tm_hit
# Out:
#        연도   팀명     타율    경기      타석  ...    홈런      루타     타점  희생번트  희생플라이
# 0    2001   두산  0.303  61.0  2482.0  ...  61.0   980.0  360.0  10.0   35.0
# 1    2001   KT  0.297  61.0  2443.0  ...  72.0   990.0  335.0  22.0   21.0
# 2    2001   NC  0.291  60.0  2407.0  ...  87.0  1013.0  372.0  20.0   21.0
# 3    2001   LG  0.281  61.0  2391.0  ...  55.0   886.0  316.0  23.0   26.0
# 4    2001  KIA  0.276  59.0  2275.0  ...  65.0   847.0  293.0  23.0   15.0
# ..    ...  ...    ...   ...     ...  ...   ...     ...    ...   ...    ...
# 195  2020   롯데  0.275  59.0  2333.0  ...  51.0   833.0  275.0  16.0   20.0
# 196  2020   키움  0.271  63.0  2495.0  ...  70.0   934.0  330.0  14.0   27.0
# 197  2020   삼성  0.271  62.0  2368.0  ...  56.0   856.0  307.0  18.0   26.0
# 198  2020   SK  0.242  62.0  2341.0  ...  53.0   746.0  222.0  23.0   12.0
# 199  2020   한화  0.242  62.0  2304.0  ...  35.0   696.0  211.0  16.0    8.0
#
# [200 rows x 15 columns]

# %%
tp = pd.read_csv( '/content/drive/My Drive/Colab Notebooks/data_project/team_pitcher.csv', sep=',', encoding='cp949' )
tm_pit = tp.drop('Unnamed: 0', axis = 1)
tm_pit
# Out:
#        연도   팀명  평균자책점    경기    승리  ...    사구     삼진     실점    자책점 이닝당출루허용률
# 0    2001  KIA   4.30  59.0  32.0  ...  19.0  453.0  274.0  247.0     1.36
# 1    2001   삼성   4.46  62.0  32.0  ...  31.0  385.0  301.0  270.0     1.43
# 2    2001   NC   4.58  60.0  40.0  ...  32.0  435.0  289.0  276.0     1.36
# 3    2001   롯데   4.62  59.0  29.0  ...  20.0  402.0  300.0  273.0     1.37
# 4    2001   키움   4.72  63.0  37.0  ...  32.0  400.0  319.0  292.0     1.40
# ..    ...  ...    ...   ...   ...  ...   ...    ...    ...    ...      ...
# 195  2020   LG   4.78  61.0  31.0  ...  34.0  426.0  325.0  291.0     1.46
# 196  2020   SK   4.82  62.0  19.0  ...  33.0  427.0  325.0  291.0     1.52
# 197  2020   두산   5.11  61.0  36.0  ...  25.0  406.0  344.0  309.0     1.52
# 198  2020   KT   5.34  61.0  31.0  ...  30.0  350.0  340.0  321.0     1.49
# 199  2020   한화   5.50  62.0  17.0  ...  35.0  468.0  369.0  330.0     1.65
#
# [200 rows x 18 columns]

# %%
tr = pd.read_csv( '/content/drive/My Drive/Colab Notebooks/data_project/team_runner.csv', sep=',', encoding='cp949' )
tm_run = tr.drop('Unnamed: 0', axis = 1)
tm_run
# Out:
#        연도   팀명    경기  도루시도  도루허용  도루실패  도루성공률   주루사  견제사
# 0    2001   삼성  62.0  78.0  53.0  25.0   67.9  21.0  7.0
# 1    2001   롯데  59.0  58.0  44.0  14.0   75.9  19.0  2.0
# 2    2001   KT  61.0  59.0  43.0  16.0   72.9  28.0  3.0
# 3    2001   키움  63.0  51.0  42.0   9.0   82.4  11.0  6.0
# 4    2001   LG  61.0  58.0  38.0  20.0   65.5  26.0  1.0
# ..    ...  ...   ...   ...   ...   ...    ...   ...  ...
# 195  2020   NC  60.0  52.0  38.0  14.0   73.1  14.0  4.0
# 196  2020   SK  62.0  53.0  33.0  20.0   62.3  14.0  9.0
# 197  2020   한화  62.0  48.0  32.0  16.0   66.7  22.0  2.0
# 198  2020   두산  61.0  42.0  29.0  13.0   69.0  22.0  1.0
# 199  2020  KIA  59.0  26.0  19.0   7.0   73.1  16.0  3.0
#
# [200 rows x 9 columns]

# %%
re_hit_main = pd.read_csv( '/content/drive/My Drive/Colab Notebooks/data_project/kbreport_hit_main.csv', sep=',', encoding='cp949' )
re_hit_main = re_hit_main.drop('Unnamed: 0', axis = 1)
re_hit_main
# Out:
#        연도  월  순위    팀명  경기  승  무  ...  BABIP     타율    출루율    장타율    OPS   wOBA  WAR
# 0    2015  3   1    롯데   3  3  0  ...  0.379  0.303  0.415  0.525  0.940  0.413    -
# 1    2015  3   2    두산   2  2  0  ...  0.268  0.297  0.352  0.516  0.868  0.372    -
# 2    2015  3   3   KIA   2  2  0  ...  0.260  0.283  0.380  0.550  0.930  0.402    -
# 3    2015  3   4    삼성   3  2  0  ...  0.347  0.319  0.379  0.469  0.848  0.379    -
# 4    2015  3   5    한화   2  1  0  ...  0.310  0.257  0.385  0.351  0.736  0.348    -
# ..    ... ..  ..   ...  .. .. ..  ...    ...    ...    ...    ...    ...    ...  ...
# 405  2020  7   6    롯데  14  6  0  ...  0.323  0.295  0.363  0.448  0.811  0.361    -
# 406  2020  7   7  Hero  15  6  0  ...  0.329  0.290  0.369  0.444  0.813  0.364    -
# 407  2020  7   8    SK  15  6  0  ...  0.300  0.263  0.330  0.386  0.716  0.322    -
# 408  2020  7   9    한화  15  5  0  ...  0.284  0.237  0.318  0.328  0.646  0.299    -
# ...

# %%
re_hit_std = pd.read_csv( '/content/drive/My Drive/Colab Notebooks/data_project/kbreport_hit_standard.csv', sep=',', encoding='cp949' )
re_hit_std = re_hit_std.drop('Unnamed: 0', axis = 1)
re_hit_std
# Out:
#        연도  월  순위    팀명  경기   타석   타수   안타  ...  HBP   삼진  희플  희타  병살  도루  도실     타율
# 0    2015  3   1    롯데   3  119   99   30  ...    2   28   0   1   1   4   0  0.303
# 1    2015  3   2    두산   2   72   64   19  ...    0    5   1   1   2   1   0  0.297
# 2    2015  3   3   KIA   2   73   60   17  ...    1    7   1   3   1   2   0  0.283
# 3    2015  3   4    삼성   3  125  113   36  ...    1   15   0   1   1   8   0  0.319
# 4    2015  3   5    한화   2   95   74   19  ...    3   16   1   5   1   6   0  0.257
# ..    ... ..  ..   ...  ..  ...  ...  ...  ...  ...  ...  ..  ..  ..  ..  ..    ...
# 395  2020  7   6    롯데  16  631  556  159  ...    7   96   6  13  19  13   0  0.286
# 396  2020  7   7  Hero  17  668  583  164  ...    6  113   6   8  17  17   0  0.281
# 397  2020  7   8    SK  17  646  575  146  ...    6  124   3   9  11   9   0  0.254
# 398  2020  7   9    LG  16  628  551  138  ...   12  111   4  10  10   5   0  0.250
# ...

# %%
re_hit_det = pd.read_csv( '/content/drive/My Drive/Colab Notebooks/data_project/kbreport_hit_detail.csv', sep=',', encoding='cp949' )
re_hit_det = re_hit_det.drop('Unnamed: 0', axis = 1)
re_hit_det
# Out:
#        연도  월  순위    팀명  경기   탸셕  ...    wRC   SPD   wSB     도실   wOBA  wRAA
# 0    2015  3   1    롯데   3  119  ...  22.45  5.43  0.77  0.413   7.16     -
# 1    2015  3   2    두산   2   72  ...  10.87  5.37  0.22  0.372   1.62     -
# 2    2015  3   3   KIA   2   73  ...  13.04  5.88  0.39  0.402   3.66     -
# 3    2015  3   4    삼성   3  125  ...  19.71  5.63  1.43  0.379   3.65     -
# 4    2015  3   5    한화   2   95  ...  12.27  4.87  1.08  0.348   0.07     -
# ..    ... ..  ..   ...  ..  ...  ...    ...   ...   ...    ...    ...   ...
# 405  2020  7   6    롯데  14  563  ...  79.56  4.65  2.45  0.361   7.22     -
# 406  2020  7   7  Hero  15  595  ...  85.66  5.15  2.66  0.364   9.21     -
# 407  2020  7   8    SK  15  575  ...  61.01  4.32  1.94  0.322 -12.87     -
# 408  2020  7   9    한화  15  564  ...  47.68  3.24  1.75  0.299 -24.79     -
# 409  2020  7  10    LG  14  562  ...  66.21  4.63  1.08  0.335  -6.00     -
#
# [410 rows x 22 columns]

# %%
re_pit_main = pd.read_csv( '/content/drive/My Drive/Colab Notebooks/data_project/kbreport_pit_main.csv', sep=',', encoding='cp949' )
re_pit_main = re_pit_main.drop('Unnamed: 0', axis = 1)
re_pit_main
# Out:
#        연도  월  순위    팀명  경기  팀승  ...  LOB%   ERA RA9-WAR   FIP  kFIP   WAR
# 0    2015  3   1    두산   2   2  ...  80.0  2.50    0.76  3.78  4.01  0.39
# 1    2015  3   2   KIA   2   2  ...  75.9  3.50    0.96  3.45  3.55  0.40
# 2    2015  3   3    롯데   3   3  ...  74.1  5.04    0.76  5.06  5.21  0.49
# 3    2015  3   4    삼성   3   2  ...  63.6  4.67    0.64  4.21  4.30  0.39
# 4    2015  3   5    한화   2   1  ...  78.5  3.54    1.08  5.29  5.46  0.22
# ..    ... ..  ..   ...  ..  ..  ...   ...   ...     ...   ...   ...   ...
# 405  2020  7   6  Hero  16   7  ...  62.0  7.09   -0.46  5.66  5.73  0.31
# 406  2020  7   7    롯데  15   6  ...  61.9  5.40    0.89  5.27  5.27  0.99
# 407  2020  7   8    SK  16   6  ...  67.0  5.48    1.67  5.08  5.17  1.16
# 408  2020  7   9    LG  15   5  ...  65.2  5.37    1.52  4.97  4.96  1.77
# 409  2020  7  10    한화  16   5  ...  74.8  4.51    2.64  5.09  5.06  1.46
#
# [410 rows x 22 columns]

# %%
re_pit_std = pd.read_csv( '/content/drive/My Drive/Colab Notebooks/data_project/kbreport_pit_standard.csv', sep=',', encoding='cp949' )
re_pit_std = re_pit_std.drop('Unnamed: 0', axis = 1)
re_pit_std
# Out:
#        연도  월  순위    팀명  경기  승   패  세  홀드  ...   삼진  볼넷  고4  HBP  폭투  보크  PK  도루  도실
# 0    2015  3   1    두산   2  2   0  1   3  ...    9   6   0    1   0   1   0   2   2
# 1    2015  3   2   KIA   2  2   0  1   1  ...   12   7   0    0   1   0   0   3   1
# 2    2015  3   3    롯데   3  3   0  1   5  ...   19  17   2    1   0   0   0   2   3
# 3    2015  3   4    삼성   3  2   1  1   3  ...   21  14   0    1   0   0   1   1   3
# 4    2015  3   5    한화   2  1   1  1   2  ...   14  10   0    2   1   0   2   2   0
# ..    ... ..  ..   ...  .. ..  .. ..  ..  ...  ...  ..  ..  ...  ..  ..  ..  ..  ..
# 405  2020  7   6  Hero  16  7   9  5  11  ...   99  60   0    7   6   0   1   7   5
# 406  2020  7   7    롯데  15  6   9  2   7  ...   96  49   2    4  14   0   0  10   2
# 407  2020  7   8    SK  16  6  10  4  10  ...  100  71   1    7  13   0   0  26   8
# 408  2020  7   9    LG  15  5   9  1   4  ...   97  39   0    5   3   0   1   8   8
# ...

# %%
re_pit_det = pd.read_csv( '/content/drive/My Drive/Colab Notebooks/data_project/kbreport_pit_detail.csv', sep=',', encoding='cp949' )
re_pit_det = re_pit_det.drop('Unnamed: 0', axis = 1)
re_pit_det
# Out:
#        연도  월  순위    팀명  경기  QS  ...  LOB%   ERA  RA9-WAR   FIP  kFIP   WAR
# 0    2015  3   1    두산   2   1  ...  80.0  2.50     0.76  3.78  4.01  0.39
# 1    2015  3   2   KIA   2   1  ...  75.9  3.50     0.96  3.45  3.55  0.40
# 2    2015  3   3    롯데   3   2  ...  74.1  5.04     0.76  5.06  5.21  0.49
# 3    2015  3   4    삼성   3   1  ...  63.6  4.67     0.64  4.21  4.30  0.39
# 4    2015  3   5    한화   2   1  ...  78.5  3.54     1.08  5.29  5.46  0.22
# ..    ... ..  ..   ...  ..  ..  ...   ...   ...      ...   ...   ...   ...
# 405  2020  7   6  Hero  16   4  ...  62.0  7.09    -0.46  5.66  5.73  0.31
# 406  2020  7   7    롯데  15   5  ...  61.9  5.40     0.89  5.27  5.27  0.99
# 407  2020  7   8    SK  16   7  ...  67.0  5.48     1.67  5.08  5.17  1.16
# 408  2020  7   9    LG  15  10  ...  65.2  5.37     1.52  4.97  4.96  1.77
# 409  2020  7  10    한화  16   4  ...  74.8  4.51     2.64  5.09  5.06  1.46
#
# [410 rows x 24 columns]
