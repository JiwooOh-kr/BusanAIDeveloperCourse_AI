# %%
from selenium import webdriver as wd
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-f30efc48433d> in <module>()
# ----> 1 from selenium import webdriver as wd
#       2 import pandas as pd
#
# ModuleNotFoundError: No module named 'selenium'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
driver = wd.Chrome('./tool/chromedriver.exe')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-cd892ff75217> in <module>()
# ----> 1 driver = wd.Chrome('./tool/chromedriver.exe')
#
# NameError: name 'wd' is not defined

# %%
import time
for n in range(2):
    target_site = 'http://www.giantsclub.com/html/?pcode=296'
    driver.get(target_site)
    time.sleep(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-af499a248e7e> in <module>()
#       2 for n in range(2):
#       3     target_site = 'http://www.giantsclub.com/html/?pcode=296'
# ----> 4     driver.get(target_site)
#       5     time.sleep(5)
#
# NameError: name 'driver' is not defined

# %%
YEARS = [ option.get_attribute('value')
 for option in driver.find_elements_by_css_selector('#year_p > option')
    if option.get_attribute('value') 
]
YEARS[:2]
# Out:
# ['2020', '2019']

# %%
data = list()
for year in YEARS[0:6]:
    year_sel = driver.find_element_by_id('year_p')
    year_sel.send_keys( year )
    driver.find_element_by_xpath('//*[@id="cont_wrapper"]/div/div[2]/div/form/input').click()
    time.sleep(5)
    
    # 데이터
    
    results = list()
    for td in driver.find_elements_by_css_selector('#tbl-rank > tbody > tr') :
        results.append(td.text.split())
        
    for i in range(0, len(results)) :
        if len(results[i]) == 18 :
            data.append({
                '연도' : year,
                '월' : results[i][0],
                '경기수' : results[i][1],
                '타수' : results[i][2],
                '피안타' : results[i][3],
                '자책점' : results[i][4],
                '승' : results[i][5],
                '패' : results[i][6],
                '세이브' : results[i][7],
                '홀드' : results[i][8],
                '이닝' : (results[i][9]+" "+results[i][10]),
                '탈삼진' : results[i][11],
                '볼넷' : results[i][12],
                '방어율' : results[i][13],
                '피홈런' : results[i][14],
                '사구' : results[i][15],
                '실점' : results[i][16],
                '피안타율' : results[i][17]
            })
        else :
            data.append({
                '연도' : year,
                '월' : results[i][0],
                '경기수' : results[i][1],
                '타수' : results[i][2],
                '피안타' : results[i][3],
                '자책점' : results[i][4],
                '승' : results[i][5],
                '패' : results[i][6],
                '세이브' : results[i][7],
                '홀드' : results[i][8],
                '이닝' : results[i][9],
                '탈삼진' : results[i][10],
                '볼넷' : results[i][11],
                '방어율' : results[i][12],
                '피홈런' : results[i][13],
                '사구' : results[i][14],
                '실점' : results[i][15],
                '피안타율' : results[i][16]
            })

# %%
df = pd.DataFrame(data)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d1192c0ddc6b> in <module>()
# ----> 1 df = pd.DataFrame(data)
#       2 df
#
# NameError: name 'pd' is not defined

# %%
df.to_csv('./LotteMonthPitcher.csv', sep=',', encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-99a5164fa2cc> in <module>()
# ----> 1 df.to_csv('./LotteMonthPitcher.csv', sep=',', encoding='utf-8')
#
# NameError: name 'df' is not defined

# %%
# 닫기 (창닫고, 프로세스도 종료)
driver.close()
driver.quit()
