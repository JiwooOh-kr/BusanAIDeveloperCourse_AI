# %%
import numpy as np
import pandas as pd

# %%
path = '/content/drive/My Drive/data_project/'
catcher = pd.read_csv(path + '현정s/csv/포지션별 상관분석 최종csv/KBO_CATCHER.csv', encoding='cp949')
catcher = catcher.drop('Unnamed: 0', axis = 1)

# %%
catcher = catcher.iloc[:, [0,1,5]]
catcher
# Out:
#       연도   팀명        타율
# 0   2015  KIA  0.211500
# 1   2015   KT  0.255667
# 2   2015   LG  0.240000
# 3   2015   NC  0.261000
# 4   2015   SK  0.249250
# 5   2015   두산  0.239000
# 6   2015   롯데  0.235000
# 7   2015   삼성  0.316750
# 8   2015   키움  0.256000
# 9   2015   한화  0.198250
# 10  2016  KIA  0.212750
# 11  2016   KT  0.228333
# 12  2016   LG  0.214750
# 13  2016   NC  0.281333
# 14  2016   SK  0.243000
# 15  2016   두산  0.229250
# 16  2016   롯데  0.274500
# 17  2016   삼성  0.185667
# 18  2016   키움  0.220500
# 19  2016   한화  0.204667
# 20  2017  KIA  0.209000
# 21  2017   KT  0.223333
# 22  2017   LG  0.259333
# 23  2017   NC  0.220600
# 24  2017   SK  0.236333
# 25  2017   두산  0.298000
# 26  2017   롯데  0.156333
# 27  2017   삼성  0.224600
# 28  2017   키움  0.210667
# 29  2017   한화  0.216600
# 30  2018  KIA  0.232250
# 31  2018   KT  0.241333
# 32  2018   LG  0.259500
# 33  2018   NC  0.174600
# 34  2018   SK  0.281333
# 35  2018   두산  0.341667
# 36  2018   롯데  0.181500
# ...

# %%
catcher.to_csv('CATCHER.csv', encoding='cp949')
