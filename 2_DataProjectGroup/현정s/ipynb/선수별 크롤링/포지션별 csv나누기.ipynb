# %%
# 1. 모듈 가져오기
import numpy as np
import pandas as pd

# %% [markdown]
# # 파일 불러오기

# %%
path = '/content/drive/My Drive/data_project/miniproject/'

# %%
kbo_all_pit = pd.read_csv( path + 'csv/KBO선수 기록/KBO_ALL_PITCHERS_Final.csv', sep=',', encoding='cp949' )
kbo_all_pit = kbo_all_pit.drop('Unnamed: 0', axis = 1)
kbo_all_hit = pd.read_csv( path + 'csv/KBO선수 기록/KBO_ALL_Hitters_Final.csv', sep=',', encoding='cp949' )
kbo_all_hit = kbo_all_hit.drop('Unnamed: 0', axis = 1)
rank = pd.read_csv(path + 'rank_season.csv', sep=',', encoding='cp949')
rank = rank.drop('Unnamed: 0', axis = 1)

# %%
kbo_all_pit.head()
# Out:
#      연도 선수이름  팀명 포지션  경기수  선발경기  ...  볼넷  사구   삼진  실점  자책점  이닝당_출루허용률
# 0  2015  조상우  키움  투수   70     0  ...  41   6   89  36   32       1.14
# 1  2015  손승락  키움  투수   58     0  ...  13   3   63  35   26       1.40
# 2  2015  김영민  키움  투수   57     4  ...  28   7   85  47   44       1.31
# 3  2015  김대우  키움  투수   47     1  ...  31   6   63  44   39       1.58
# 4  2015  한현희  키움  투수   45    17  ...  41  13  122  70   66       1.35
#
# [5 rows x 31 columns]

# %%
kbo_all_hit.head()
# Out:
#      연도 선수이름  팀명  포지션  경기수  선발경기  ...  3루타  홈런   루타   타점  희생번트  희생플라이
# 0  2015  김하성  키움  유격수  140   139  ...    5  19  250   73     4      6
# 1  2015  박병호  키움  1루수  131   131  ...    1  53  377  146     0      4
# 2  2015  박동원  키움   포수  126   122  ...    1  14  157   61    10      8
# 3  2015  유한준  키움  우익수   81    68  ...    1  23  301  116     1      8
# 4  2015  유한준  키움  중견수   70    61  ...    1  23  301  116     1      8
#
# [5 rows x 29 columns]

# %%
rank
# Out:
#       연도  순위   팀명
# 0   2015   1   두산
# 1   2015   2   삼성
# 2   2015   3   NC
# 3   2015   4   키움
# 4   2015   5   SK
# 5   2015   6   한화
# 6   2015   7  KIA
# 7   2015   8   롯데
# 8   2015   9   LG
# 9   2015  10   KT
# 10  2016   1   두산
# 11  2016   2   NC
# 12  2016   3   키움
# 13  2016   4   LG
# 14  2016   5  KIA
# 15  2016   6   SK
# 16  2016   7   한화
# 17  2016   8   롯데
# 18  2016   9   삼성
# 19  2016  10   KT
# 20  2017   1  KIA
# 21  2017   2   두산
# 22  2017   3   롯데
# 23  2017   4   NC
# 24  2017   5   SK
# 25  2017   6   LG
# 26  2017   7   키움
# 27  2017   8   한화
# 28  2017   9   삼성
# 29  2017  10   KT
# 30  2018   1   SK
# 31  2018   2   두산
# 32  2018   3   한화
# 33  2018   4   키움
# 34  2018   5  KIA
# 35  2018   6   삼성
# 36  2018   7   롯데
# 37  2018   8   LG
# 38  2018   9   KT
# 39  2018  10   NC
# 40  2019   1   두산
# 41  2019   2   키움
# 42  2019   3   SK
# 43  2019   4   LG
# 44  2019   5   NC
# 45  2019   6   KT
# 46  2019   7  KIA
# 47  2019   8   삼성
# 48  2019   9   한화
# ...

# %% [markdown]
# # 1루수

# %%
kbo_all_hit_first = kbo_all_hit[ kbo_all_hit['포지션'] == '1루수' ]
kbo_all_hit_first.shape
# Out:
# (318, 29)

# %%
kbo_all_hit_first
# Out:
#         연도 선수이름  팀명  포지션  경기수  선발경기  ...  3루타  홈런   루타   타점  희생번트  희생플라이
# 1     2015  박병호  키움  1루수  131   131  ...    1  53  377  146     0      4
# 8     2015  윤석민  키움  1루수    8     7  ...    1  14  174   71     5      7
# 23    2015  서동욱  키움  1루수   13     6  ...    0   3   38   15     1      0
# 29    2015  유재신  키움  1루수   14     0  ...    0   0    9    3     2      0
# 34    2015  임병욱  키움  1루수    7     0  ...    1   1   14    3     0      0
# ...    ...  ...  ..  ...  ...   ...  ...  ...  ..  ...  ...   ...    ...
# 2330  2020   로맥  SK  1루수   60    60  ...    0  13  115   36     0      1
# 2363  2020  윤석민  SK  1루수    5     2  ...    0   1   14    8     0      1
# 2364  2020  남태혁  SK  1루수    5     2  ...    0   1   16   10     0      0
# 2365  2020  채태인  SK  1루수    4     4  ...    0   2   28   13     0      0
# 2368  2020  이거연  SK  1루수    2     0  ...    0   0    1    0     0      0
#
# [318 rows x 29 columns]

# %%
kbo_all_hit_first.to_csv('KBO_1루수.csv', encoding='cp949')

# %% [markdown]
# # 2루수

# %%
kbo_all_hit_second = kbo_all_hit[ kbo_all_hit['포지션'] == '2루수' ]
kbo_all_hit_second.shape
# Out:
# (302, 29)

# %%
kbo_all_hit_second
# Out:
#         연도 선수이름  팀명  포지션  경기수  선발경기  ...  3루타  홈런   루타  타점  희생번트  희생플라이
# 6     2015  서건창  키움  2루수   72    67  ...    4   3  134  37    11      2
# 10    2015  김민성  키움  2루수   36    32  ...    0  16  207  71     2      3
# 11    2015  김지수  키움  2루수   67    24  ...    0   0   38  13     7      1
# 22    2015  서동욱  키움  2루수   33    16  ...    0   3   38  15     1      0
# 38    2015  송성문  키움  2루수    5     5  ...    0   0    3   1     0      0
# ...    ...  ...  ..  ...  ...   ...  ...  ...  ..  ...  ..   ...    ...
# 2329  2020  최정원  NC  2루수    2     0  ...    0   0    4   1     0      0
# 2335  2020  김성현  SK  2루수   25     6  ...    0   0   33   7     6      1
# 2338  2020  최준우  SK  2루수   39    37  ...    0   3   49  12     3      0
# 2354  2020  김창평  SK  2루수   17    16  ...    1   0   13   5     0      0
# 2356  2020   최항  SK  2루수   12     9  ...    0   0    6   3     0      0
#
# [302 rows x 29 columns]

# %%
kbo_all_hit_second.to_csv('KBO_2루수.csv', encoding='cp949')

# %% [markdown]
# # 3루수

# %%
kbo_all_hit_third = kbo_all_hit[ kbo_all_hit['포지션'] == '3루수' ]
kbo_all_hit_third.shape
# Out:
# (334, 29)

# %%
kbo_all_hit_third
# Out:
#         연도 선수이름  팀명  포지션  경기수  선발경기  ...  3루타  홈런   루타  타점  희생번트  희생플라이
# 7     2015  윤석민  키움  3루수   72    64  ...    1  14  174  71     5      7
# 9     2015  김민성  키움  3루수   69    62  ...    0  16  207  71     2      3
# 12    2015  김지수  키움  3루수   22     5  ...    0   0   38  13     7      1
# 24    2015  서동욱  키움  3루수    3     1  ...    0   3   38  15     1      0
# 32    2015  장시윤  키움  3루수   12    10  ...    0   0    8   2     2      0
# ...    ...  ...  ..  ...  ...   ...  ...  ...  ..  ...  ..   ...    ...
# 2332  2020   최정  SK  3루수   59    56  ...    0  15  122  42     0      2
# 2337  2020   정현  SK  3루수    4     1  ...    0   1   21   2     3      0
# 2339  2020  최준우  SK  3루수    3     0  ...    0   3   49  12     3      0
# 2357  2020   최항  SK  3루수    2     1  ...    0   0    6   3     0      0
# 2362  2020  윤석민  SK  3루수    9     8  ...    0   1   14   8     0      1
#
# [334 rows x 29 columns]

# %%
kbo_all_hit_third.to_csv('KBO_3루수.csv', encoding='cp949')

# %% [markdown]
# # 유격수

# %%
kbo_all_hit_short = kbo_all_hit[ kbo_all_hit['포지션'] == '유격수' ]
kbo_all_hit_short.shape
# Out:
# (233, 29)

# %%
kbo_all_hit_short
# Out:
#         연도 선수이름  팀명  포지션  경기수  선발경기  ...  3루타  홈런   루타  타점  희생번트  희생플라이
# 0     2015  김하성  키움  유격수  140   139  ...    5  19  250  73     4      6
# 13    2015  김지수  키움  유격수   16     2  ...    0   0   38  13     7      1
# 33    2015  장시윤  키움  유격수    3     2  ...    0   0    8   2     2      0
# 40    2015  김재호  두산  유격수  133   128  ...    3   3  165  50    14      7
# 49    2015  허경민  두산  유격수   29    16  ...    2   1  155  41     8      3
# ...    ...  ...  ..  ...  ...   ...  ...  ...  ..  ...  ..   ...    ...
# 2325  2020  지석훈  NC  유격수    3     0  ...    0   1    7   5     0      2
# 2327  2020  박준영  NC  유격수    2     2  ...    0   0    0   0     0      0
# 2334  2020  김성현  SK  유격수   51    39  ...    0   0   33   7     6      1
# 2336  2020   정현  SK  유격수   50    28  ...    0   1   21   2     3      0
# 2366  2020  유서준  SK  유격수    3     1  ...    0   0    2   0     0      0
#
# [233 rows x 29 columns]

# %%
kbo_all_hit_short.to_csv('KBO_유격수.csv', encoding='cp949')

# %% [markdown]
# # 중견수

# %%
kbo_all_hit_center = kbo_all_hit[ kbo_all_hit['포지션'] == '중견수' ]
kbo_all_hit_center.shape
# Out:
# (279, 29)

# %%
kbo_all_hit_center
# Out:
#         연도  선수이름  팀명  포지션  경기수  선발경기  ...  3루타  홈런   루타   타점  희생번트  희생플라이
# 4     2015   유한준  키움  중견수   70    61  ...    1  23  301  116     1      8
# 5     2015   이택근  키움  중견수   81    72  ...    1  10  161   44     3      4
# 17    2015  스나이더  키움  중견수    4     1  ...    1  26  227   71     3      5
# 21    2015   박헌도  키움  중견수    3     1  ...    0   8   91   42     3      2
# 27    2015   문우람  키움  중견수   10     5  ...    0   2   44   22     1      3
# ...    ...   ...  ..  ...  ...   ...  ...  ...  ..  ...  ...   ...    ...
# 2320  2020   김준완  NC  중견수    5     0  ...    0   1    8    3     0      0
# 2333  2020   김강민  SK  중견수   51    30  ...    1   5   57   20     1      2
# 2343  2020   최지훈  SK  중견수   17    17  ...    1   1   60    9     4      1
# 2346  2020   정진기  SK  중견수    7     6  ...    2   2   42   15     4      2
# 2359  2020   김경호  SK  중견수    7     3  ...    0   0   10    1     0      0
#
# [279 rows x 29 columns]

# %%
kbo_all_hit_center.to_csv('KBO_중견수.csv', encoding='cp949')

# %% [markdown]
# # 우익수

# %%
kbo_all_hit_right = kbo_all_hit[ kbo_all_hit['포지션'] == '우익수' ]
kbo_all_hit_right.shape
# Out:
# (340, 29)

# %%
kbo_all_hit_right
# Out:
#         연도  선수이름  팀명  포지션  경기수  선발경기  ...  3루타  홈런   루타   타점  희생번트  희생플라이
# 3     2015   유한준  키움  우익수   81    68  ...    1  23  301  116     1      8
# 15    2015  스나이더  키움  우익수   60    53  ...    1  26  227   71     3      5
# 20    2015   박헌도  키움  우익수   17     7  ...    0   8   91   42     3      2
# 25    2015   문우람  키움  우익수   26    12  ...    0   2   44   22     1      3
# 35    2015   임병욱  키움  우익수    4     1  ...    1   1   14    3     0      0
# ...    ...   ...  ..  ...  ...   ...  ...  ...  ..  ...  ...   ...    ...
# 2348  2020   정의윤  SK  우익수    2     2  ...    1   1   44   14     0      2
# 2349  2020   한동민  SK  우익수   23    22  ...    0   9   55   19     0      2
# 2352  2020   오준혁  SK  우익수    2     1  ...    0   2   31    9     0      0
# 2360  2020   김경호  SK  우익수    2     1  ...    0   0   10    1     0      0
# 2367  2020   김재현  SK  우익수    2     1  ...    0   0    0    0     0      0
#
# [340 rows x 29 columns]

# %%
kbo_all_hit_right.to_csv('KBO_우익수.csv', encoding='cp949')

# %% [markdown]
# # 좌익수

# %%
kbo_all_hit_left = kbo_all_hit[ kbo_all_hit['포지션'] == '좌익수' ]
kbo_all_hit_left.shape
# Out:
# (352, 29)

# %%
kbo_all_hit_left
# Out:
#         연도  선수이름  팀명  포지션  경기수  선발경기  ...  3루타  홈런   루타  타점  희생번트  희생플라이
# 14    2015   고종욱  키움  좌익수   66    57  ...    4  10  189  51     4      1
# 16    2015  스나이더  키움  좌익수   50    39  ...    1  26  227  71     3      5
# 19    2015   박헌도  키움  좌익수   54    37  ...    0   8   91  42     3      2
# 26    2015   문우람  키움  좌익수   17     5  ...    0   2   44  22     1      3
# 31    2015   유재신  키움  좌익수    4     0  ...    0   0    9   3     2      0
# ...    ...   ...  ..  ...  ...   ...  ...  ...  ..  ...  ..   ...    ...
# 2345  2020   정진기  SK  좌익수   10     6  ...    2   2   42  15     4      2
# 2347  2020   정의윤  SK  좌익수   23    18  ...    1   1   44  14     0      2
# 2351  2020   오준혁  SK  좌익수   20    17  ...    0   2   31   9     0      0
# 2358  2020   김경호  SK  좌익수   10     4  ...    0   0   10   1     0      0
# 2361  2020   고종욱  SK  좌익수    9     9  ...    2   0   23   9     0      0
#
# [352 rows x 29 columns]

# %%
kbo_all_hit_left.to_csv('KBO_좌익수.csv', encoding='cp949')

# %% [markdown]
# # 포수

# %%
kbo_all_hit_catcher = kbo_all_hit[ kbo_all_hit['포지션'] == '포수' ]
kbo_all_hit_catcher.shape
# Out:
# (203, 29)

# %%
kbo_all_hit_catcher
# Out:
#         연도 선수이름  팀명 포지션  경기수  선발경기  ...  3루타  홈런   루타  타점  희생번트  희생플라이
# 2     2015  박동원  키움  포수  126   122  ...    1  14  157  61    10      8
# 18    2015  김재현  키움  포수   58    15  ...    0   1   23   6     2      1
# 28    2015  유선정  키움  포수   17     7  ...    0   0    6   2     0      0
# 41    2015  양의지  두산  포수  129   123  ...    0  20  231  93     2      6
# 51    2015  최재훈  두산  포수   69    21  ...    0   0   18   7     3      1
# ...    ...  ...  ..  ..  ...   ...  ...  ...  ..  ...  ..   ...    ...
# 2326  2020  김형준  NC  포수    5     2  ...    0   0    4   1     0      0
# 2340  2020  이현석  SK  포수   37    22  ...    0   2   23   6     2      0
# 2350  2020  이홍구  SK  포수   22    16  ...    0   1   13   3     0      1
# 2353  2020  이흥련  SK  포수   19    16  ...    0   2   22   9     0      1
# 2355  2020  이재원  SK  포수   15    14  ...    0   0    5   3     0      0
#
# [203 rows x 29 columns]

# %%
kbo_all_hit_catcher.to_csv('KBO_포수.csv', encoding='cp949')

# %% [markdown]
# # 투수

# %%
kbo_all_pit
# Out:
#         연도 선수이름  팀명 포지션  경기수  선발경기  ...  볼넷  사구   삼진  실점  자책점  이닝당_출루허용률
# 0     2015  조상우  키움  투수   70     0  ...  41   6   89  36   32       1.14
# 1     2015  손승락  키움  투수   58     0  ...  13   3   63  35   26       1.40
# 2     2015  김영민  키움  투수   57     4  ...  28   7   85  47   44       1.31
# 3     2015  김대우  키움  투수   47     1  ...  31   6   63  44   39       1.58
# 4     2015  한현희  키움  투수   45    17  ...  41  13  122  70   66       1.35
# ...    ...  ...  ..  ..  ...   ...  ...  ..  ..  ...  ..  ...        ...
# 1016  2020  김세현  SK  투수   10     0  ...   4   0    6   7    7       1.73
# 1017  2020  김주한  SK  투수    8     5  ...  12   5    7  22   20       1.90
# 1018  2020  신재웅  SK  투수    5     0  ...   2   0    2   2    2       2.10
# 1019  2020  백승건  SK  투수    4     2  ...  10   0   13  11   11       2.15
# 1020  2020   킹엄  SK  투수    2     2  ...   4   0    6  11    8       1.88
#
# [1021 rows x 31 columns]
