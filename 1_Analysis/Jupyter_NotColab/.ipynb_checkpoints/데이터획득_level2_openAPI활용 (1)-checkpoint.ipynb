# %% [markdown]
# # 데이터 획득 - level 2
#
# - open api 활용
# - request 모듈 사용

# %% [markdown]
# # open api 사용 신청 및 키 획득
#
# - dev.naver.com
# - 로그인
# - 신규 강비 경우, 인증 후 이용 가능
# - 어플리케이션 새로 생성
#     - 이름, url, 운영환경(Web)
# - 아래 키는 보안 유지
#     - client ID : i541VrlJuD9Sk8TONeYn
#     - client Secret : fx_GgrAFnH
# - 검색
#     - https://developers.naver.com/docs/search/news/
#     - URL : https://openapi.naver.com/v1/search/news.json
#     - GET 방식
#     - 예시
#         curl "https://openapi.naver.com/v1/search/news.xml?query=%EC%A3%BC%EC%8B%9D&display=10&start=1&sort=sim" \
#         -H "X-Naver-Client-Id: {애플리케이션 등록 시 발급받은 client id 값}" \
#         -H "X-Naver-Client-Secret: {애플리케이션 등록 시 발급받은 client secret 값}" -v

# %% [markdown]
# ![%EC%8A%A4%ED%81%AC%EB%A6%B0%EC%83%B7%281%29.png](attachment:%EC%8A%A4%ED%81%AC%EB%A6%B0%EC%83%B7%281%29.png)

# %% [markdown]
# ![%EC%8A%A4%ED%81%AC%EB%A6%B0%EC%83%B7%282%29.png](attachment:%EC%8A%A4%ED%81%AC%EB%A6%B0%EC%83%B7%282%29.png)

# %% [markdown]
# ![%EC%8A%A4%ED%81%AC%EB%A6%B0%EC%83%B7%285%29.png](attachment:%EC%8A%A4%ED%81%AC%EB%A6%B0%EC%83%B7%285%29.png)

# %% [markdown]
# ![%EC%8A%A4%ED%81%AC%EB%A6%B0%EC%83%B7%287%29.png](attachment:%EC%8A%A4%ED%81%AC%EB%A6%B0%EC%83%B7%287%29.png)

# %% [markdown]
# ![%EC%8A%A4%ED%81%AC%EB%A6%B0%EC%83%B7%288%29.png](attachment:%EC%8A%A4%ED%81%AC%EB%A6%B0%EC%83%B7%288%29.png)

# %% [markdown]
# - 검증
#     - postman을 이용해 통신이 잘 되는지 활용
#     - https://www.postman.com/downloads/

# %% [markdown]
# ![%EC%8A%A4%ED%81%AC%EB%A6%B0%EC%83%B7%289%29.png](attachment:%EC%8A%A4%ED%81%AC%EB%A6%B0%EC%83%B7%289%29.png)

# %% [markdown]
# ![%EC%8A%A4%ED%81%AC%EB%A6%B0%EC%83%B7%2811%29.png](attachment:%EC%8A%A4%ED%81%AC%EB%A6%B0%EC%83%B7%2811%29.png)

# %% [markdown]
# ![%EC%8A%A4%ED%81%AC%EB%A6%B0%EC%83%B7%2812%29.png](attachment:%EC%8A%A4%ED%81%AC%EB%A6%B0%EC%83%B7%2812%29.png)

# %%
# 필요한 모듈 가져오기
import urllib.request
import os
import sys

# %%
# 상수(값의 변동이 없음)값 저장
# 변수명을 전부 대문자로 사용하면 상수처럼 쓰겠다는 의도
CLIENT_ID = 'i541VrlJuD9Sk8TONeYn'
SECRET_ID = 'fx_GgrAFnH'

# %%
# url 정의
news_url = 'https://openapi.naver.com/v1/search/news.json'
news_url
# Out:
# 'https://openapi.naver.com/v1/search/news.json'

# %%
# parameter
# 검색어는 URL 인코딩이 되야함. UTF-8 인코딩 처리해서 요청 (why : 규격서, api 요구사항)
# 한글을 전송할 때는 %EB%B6%80... 형식으로 전송해야 정확하게 전달됨
keyword = urllib.parse.quote('부동산') 
param = 'query=' + keyword
param
# Out:
# 'query=%EB%B6%80%EB%8F%99%EC%82%B0'

# %%
news_url + '?' + param
# Out:
# 'https://openapi.naver.com/v1/search/news.json?query=%EB%B6%80%EB%8F%99%EC%82%B0'

# %%
'%s?%s' %(news_url, param)
# Out:
# 'https://openapi.naver.com/v1/search/news.json?query=%EB%B6%80%EB%8F%99%EC%82%B0'

# %%
'{}?{}'.format(news_url, param)
# Out:
# 'https://openapi.naver.com/v1/search/news.json?query=%EB%B6%80%EB%8F%99%EC%82%B0'

# %%
# python 3.6 이상부터 적용 가능
target_url = f"{news_url}?{param}"

# %%
# 통신 객체 생성
request = urllib.request.Request(target_url)

# %%
# 헤더 세팅 : key setting (key, value)
request.add_header('X-Naver-Client-Id', CLIENT_ID)
request.add_header('X-Naver-Client-Secret', SECRET_ID)

# %%
# 통신
response = urllib.request.urlopen(request)

# %%
# 응답코드(200 나오면 잘 적용된 것)
response.getcode()
# Out:
# 200

# %%
import json

if response.getcode() == 200 :
    # 통신 성공 시 처리 → postman으로 통신 수행 및 응답결과 확인(구조 확인)
    # 결과는 json → json 처리하는 모듈이 필요
    tmp = json.load(response)
    print(tmp)
    pass
else :
    # 실패 시 처리
    print('error code', response.getcode())
    pass
# Out:
# {'lastBuildDate': 'Tue, 07 Jul 2020 15:35:01 +0900', 'total': 2924867, 'start': 1, 'display': 10, 'items': [{'title': '이낙연 &quot;서울 유휴부지로 공급 늘려야&quot;, 그린벨트 해제 주장', 'originallink': 'http://www.viewsnnews.com/article?q=182484', 'link': 'http://www.viewsnnews.com/article?q=182484', 'description': '이 의원은 <b>부동산</b> 대책과 관련해선 &quot;정책의 큰 기둥은 공급 확대, 과세 강화, 과잉 유동성이 산업으로... 그는 자신이 총선 과정에 직접 고가 1가구1주택에 대한 종합<b>부동산</b>세 완화 필요성을 주장했던 데 대해선 &quot;장기거주... ', 'pubDate': 'Tue, 07 Jul 2020 15:32:00 +0900'}, {'title': '[백신프로젝트] &quot;작은 실천이 세상을 바꿉니다&quot;', 'originallink': 'http://www.honam.co.kr/detail/7gJo8W/607819', 'link': 'http://www.honam.co.kr/detail/7gJo8W/607819', 'description': "한편, 한국감정원은 <b>부동산</b>의 가격공시, 통계, 조사, <b>부동산</b> 시장관리 등 공적 업무를 수행하는 국토교통부 산하기관으로 위상을 명확히 하고자 오는 12월 '한국<b>부동산</b>원'으로 사명을 변경하고 <b>부동산</b> 시장의 공적... ", 'pubDate': 'Tue, 07 Jul 2020 15:32:00 +0900'}, {'title': '&quot;민주당 다주택자 180명 중 42명, 사과하고 집 팔아야&quot;', 'originallink': 'http://www.mediatoday.co.kr/news/articleView.html?idxno=208022', 'link': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=006&aid=0000103423', 'description': '국회의원 <b>부동산</b> 소유 현황을 조사한 결과, 여당(더불어민주당+더불어시민당)으로 당선된 180명 중 42명이... 경실련은 여당 다주택 소유 의원들, 여당소속 선출직과 임명직 공직자들이 실수요 외 <b>부동산</b>을 즉각 처분하고... ', 'pubDate': 'Tue, 07 Jul 2020 15:32:00 +0900'}, {'title': "문 대통령 앞에 놓인 '집값문제' '남북관계' '검찰개혁'…난제 어떻게 풀까?", 'originallink': 'http://www.segye.com/content/html/2020/07/07/20200707516443.html?OutUrl=naver', 'link': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=100&oid=022&aid=0003481953', 'description': '文 지지율 40%대 기록…15주 만에 처음 / <b>부동산</b> 문제 등 민생현안 이슈, 문 대통령 지지율 하락으로 이어져... 가운데, <b>부동산</b> 문제와 남북관계, 검찰개혁 등 3대 난제의 파고가 거세지고 있다고 뉴스1이 전했다. 문 대통령이... ', 'pubDate': 'Tue, 07 Jul 2020 15:32:00 +0900'}, {'title': 'AI기반 <b>부동산</b> 자산관리 <b>부동산</b>플래닛…임하나 박사 영입', 'originallink': 'http://www.dtoday.co.kr/news/articleView.html?idxno=370909', 'link': 'http://www.dtoday.co.kr/news/articleView.html?idxno=370909', 'description': '<b>부동산</b>정보 플랫폼 <b>부동산</b>플래닛을 운영하는 종합<b>부동산</b>서비스 기업 와이티파트너스(대표 정수민∙엄현포)는 서울연구원 임하나(사진) 박사를 영입 데이터랩을 설립했다고 7일 밝혔다. 와이티파트너스... ', 'pubDate': 'Tue, 07 Jul 2020 15:32:00 +0900'}, {'title': '‘빌라넷’, “젊은 연령층이 다양한 구조 신축빌라분양 선호”', 'originallink': 'http://gokorea.kr/news/view/686809', 'link': 'http://gokorea.kr/news/view/686809', 'description': '신축빌라 분양 <b>부동산</b> 정보 제공업체 ‘빌라넷’은 신축빌라로 눈을 조금만 돌리면 훨씬 더 나은 주거환경과 편리한 시설들이 있어 생각이 달라지고 있으며 많은 장점들이 있다고 설명했다. 또한 처음 내집을 마련하고자... ', 'pubDate': 'Tue, 07 Jul 2020 15:32:00 +0900'}, {'title': "정부 '다주택자 세부담 강화' <b>부동산</b> 보완책 검토", 'originallink': 'https://www.news1.kr/photos/view/?4276445', 'link': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=421&aid=0004740127', 'description': '정부가 7일 홍남기 경제부총리 겸 기획재정부 장관 주재로 관계장관회의를 열고 다주택자 세부담을 강화하는 내용의 <b>부동산</b> 보완 대책 마련에 나섰다. 다주택자와 투기성 주택보유자에 대한 종합<b>부동산</b>세를 강화하고... ', 'pubDate': 'Tue, 07 Jul 2020 15:31:00 +0900'}, {'title': "정부 '다주택자 세부담 강화' <b>부동산</b> 보완책 검토", 'originallink': 'https://www.news1.kr/photos/view/?4276446', 'link': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=421&aid=0004740128', 'description': '정부가 7일 홍남기 경제부총리 겸 기획재정부 장관 주재로 관계장관회의를 열고 다주택자 세부담을 강화하는 내용의 <b>부동산</b> 보완 대책 마련에 나섰다. 다주택자와 투기성 주택보유자에 대한 종합<b>부동산</b>세를 강화하고... ', 'pubDate': 'Tue, 07 Jul 2020 15:31:00 +0900'}, {'title': '&quot;수도권 규제는 균형발전·국가전체 성장 가져와&quot;', 'originallink': 'http://www.jbnews.com/news/articleView.html?idxno=1297677', 'link': 'http://www.jbnews.com/news/articleView.html?idxno=1297677', 'description': '이 교수는 심각한 수도권 <b>부동산</b> 가격 급등 현상도 궁극적으로 수도권 과밀 때문으로 강력한 균형발전 정책으로 수도권의 압력을 빼내야 해결할 수 있다고 역설했다. 이 교수는 &quot;강남 <b>부동산</b> 가격 억제 방법은 균형발전... ', 'pubDate': 'Tue, 07 Jul 2020 15:30:00 +0900'}, {'title': '[뉴스후] 초강력 대책도 비웃는 <b>부동산</b>시장…과열 언제까지?', 'originallink': 'https://news.mtn.co.kr/newscenter/news_viewer.mtn?gidx=2020070710383193389', 'link': 'https://news.mtn.co.kr/newscenter/news_viewer.mtn?gidx=2020070710383193389', 'description': '<b>부동산</b> 대책이 나왔지만  ...

# %%
a = "&quot;<b>부동산</b>정책 고위공직자 31%가 다주택자…이달까지 집 팔아라&quot;"
a = a.replace('<b>', '')
a = a.replace('</b>', '')
a = a.replace('&quot;', '\"')
print(a)
# Out:
# "부동산정책 고위공직자 31%가 다주택자…이달까지 집 팔아라"

# %%
# 현재 결과는 tmp에 존재
# 제목만 출력하시오

type(tmp), tmp.keys()

for item in tmp['items'] :
    print(item['title'].replace('<b>', '').replace('</b>', '').replace('&quot;', '\"'))
    
    # 만약 raw_data 중에서 불필요한 부분을 제거한다면 간단한 것은 replace(), 복잡한 것은 정규식으로 처리
    
    pass
# Out:
# 이낙연 "서울 유휴부지로 공급 늘려야", 그린벨트 해제 주장
# [백신프로젝트] "작은 실천이 세상을 바꿉니다"
# "민주당 다주택자 180명 중 42명, 사과하고 집 팔아야"
# 문 대통령 앞에 놓인 '집값문제' '남북관계' '검찰개혁'…난제 어떻게 풀까?
# AI기반 부동산 자산관리 부동산플래닛…임하나 박사 영입
# ‘빌라넷’, “젊은 연령층이 다양한 구조 신축빌라분양 선호”
# 정부 '다주택자 세부담 강화' 부동산 보완책 검토
# 정부 '다주택자 세부담 강화' 부동산 보완책 검토
# "수도권 규제는 균형발전·국가전체 성장 가져와"
# [뉴스후] 초강력 대책도 비웃는 부동산시장…과열 언제까지?
