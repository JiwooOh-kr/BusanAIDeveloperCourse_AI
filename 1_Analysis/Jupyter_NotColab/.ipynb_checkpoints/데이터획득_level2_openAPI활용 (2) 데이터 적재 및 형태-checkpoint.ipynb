# %%
# (1) 파일에서 추출

import urllib.request
import os
import sys

CLIENT_ID = 'i541VrlJuD9Sk8TONeYn'
SECRET_ID = 'fx_GgrAFnH'
news_url = 'https://openapi.naver.com/v1/search/news.json'
keyword = urllib.parse.quote('부동산') 
param = 'query=' + keyword
target_url = f"{news_url}?{param}"
request = urllib.request.Request(target_url)
request.add_header('X-Naver-Client-Id', CLIENT_ID)
request.add_header('X-Naver-Client-Secret', SECRET_ID)
response = urllib.request.urlopen(request)
response.getcode()

import json

if response.getcode() == 200 :
    tmp = json.load(response)
    pass
else :
    print('error code', response.getcode())
    pass

type(tmp), tmp.keys()

for item in tmp['items'] :
    print(item['title'].replace('<b>', '').replace('</b>', '').replace('&quot;', '\"'))
    pass
# Out:
# 돌아온 재난지원금 청구서?…나라살림 적자 78조 육박
# [천지포토] 부동산 정책 발언하는 김종인
# 원희룡 “우리도 다주택자 집 팔자”에 주호영 “반헌법적”
# [단독]똘똘한 한 채는 종부세 부담 안 높인다
# [아유경제_부동산] 경남, 서부일반산단 조성 재추진… 토지거래허가구역 다시...
# 김정재 의원, 산자위·운영위·여가위 위원 배정
# 후보 땐 팔겠다더니… “민주당 23% 다주택자, 앉아서 수억 벌어”
# 종로구, 동네배움터 온라인 강좌 운영
# "때로는 가시밭길…" 이낙연 당권 도전 선언…이강철·이기명·백원우 등 친노...
# 날아온 재산세 폭탄 고지서···"30% 올랐다" 곳곳 아우성

# %% [markdown]
# # 데이터 적재
#
# - 3단계(데이터 준비)에서 수집한 데이터를 DB에 넣어서 전달해 달라 요청함 (설정, 가정)
# - 수집한 내용을 DB에 적재하도록 함
# - Database
#     - RDBMS
#         - oracle, ms-sql, mysql, maria, 기업형DB 등
#     - NO-SQL
#         - 몽고DB 등
#     - DB는 mariaDB, sql은 사용 안 함
#         - https://mariadb.com/downloads/
#         - <a href= "https://mariadb.com/downloads/">html버전 링크</a>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![%EC%8A%A4%ED%81%AC%EB%A6%B0%EC%83%B7%2817%29.png](attachment:%EC%8A%A4%ED%81%AC%EB%A6%B0%EC%83%B7%2817%29.png)

# %% [markdown]
# ## 데이터의 형태
#
# - 데이터베이스에 데이터를 한번에 넣는 방법
#     - 데이터가 DataFrame의 구조를 가져야 함
#     - python에서 데이터 분석 시 사용하는 모듈 : pandas
#     - pandas에서 사용하는 자료 구조
#         - Series
#         - DataFrame

# %%
# Dict → DataFrame 변환
# 대상 데이터 확인
tmp['items'][0]
# Out:
# {'title': '돌아온 재난지원금 청구서?…나라살림 적자 78조 육박',
#  'originallink': 'http://news.kmib.co.kr/article/view.asp?arcid=0014775731&code=61141111&cp=nv',
#  'link': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=005&aid=0001339390',
#  'description': '5월까지 소득세 수입은 <b>부동산</b> 거래 등에 따른 양도소득 수입 증가 등의 영향으로 9000억원 감소에 그쳐 36조6000억원을 기록했다. 정부의 총지출은 1~5월 259조5000억원으로 1년 전 같은 기간보다 24조5000억원... ',
#  'pubDate': 'Tue, 07 Jul 2020 17:05:00 +0900'}

# %%
import pandas as pd

# %%
df = pd.DataFrame.from_dict(tmp['items'])
df.head(2)
# Out:
#                            title  \
# 0  돌아온 재난지원금 청구서?…나라살림 적자 78조 육박
# 1  [천지포토] <b>부동산</b> 정책 발언하는 김종인
#
#                                         originallink  \
# 0  http://news.kmib.co.kr/article/view.asp?arcid=...
# 1  http://www.newscj.com/news/articleView.html?id...
#
#                                                 link  \
# 0  https://news.naver.com/main/read.nhn?mode=LSD&...
# 1  http://www.newscj.com/news/articleView.html?id...
#
#                                          description  \
# 0  5월까지 소득세 수입은 <b>부동산</b> 거래 등에 따른 양도소득 수입 증가 등의...
# 1  미래통합당 김종인 비상대책위원장이 7일 오후 서울 여의도 국회에서 열린 <b>부동산...
#
#                            pubDate
# 0  Tue, 07 Jul 2020 17:05:00 +0900
# 1  Tue, 07 Jul 2020 17:04:00 +0900

# %%
# 데이터 수(row), column 수
df.shape
# Out:
# (10, 5)
